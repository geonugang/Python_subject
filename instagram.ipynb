# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
url = 'https://www.instagram.com/'

driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
time.sleep(1)

def get_content(driver):
  html = driver.page_source
  soup = BeautifulSoup(html, 'html.parser')
  contents_ = soup.select('div._a9zs > h1')
  contents__ = contents_[0].text
  tags = contents__.split('#')
  contents_data = tags[0]
  tags = tags[1:]
  tags = [item.strip() for item in tags]
  data = [contents_data, tags]
  return data

def move_next(driver):
  try:
    next_btn = driver.find_elements(By.CSS_SELECTOR, 'div._aaqg._aaqh > button._abl-')[0]
    next_btn.click()
    time.sleep(3)
    return True
  except:
    return False
  

id = '-'
input_id = driver.find_elements(By.CSS_SELECTOR, 'input._aa4b')[0]
input_id.clear()
time.sleep(3)
input_id.send_keys(id)



pw = '-'
input_pw = driver.find_elements(By.CSS_SELECTOR, 'input._aa4b')[1]
input_pw.clear()
input_pw.send_keys(pw)

time.sleep(3)
login_botton = driver.find_elements(By.CSS_SELECTOR, 'button._acan._acap._acas._aj1-._ap30')[0]
login_botton.click()

time.sleep(5)
late_botton = driver.find_elements(By.CSS_SELECTOR, 'div._ac8f')[0]
late_botton.click()

time.sleep(3)
late2_botton = driver.find_elements(By.CSS_SELECTOR, 'button._a9--._ap36._a9_1')[0]
late2_botton.click()

time.sleep(3)
search_botton = driver.find_elements(By.CSS_SELECTOR, 'div.xopu45v.xu3j5b3 > div.x1xgvd2v.x1cy8zhl > div.x1iyjqo2.xh8yej3 > div > span.x4k7w5x.x1h91t0o')[0]
search_botton.click()

time.sleep(3)

search_ = input('Please enter what you are searching for (like #search) : ')
search_place = driver.find_elements(By.CSS_SELECTOR, 'div.x78zum5.xdt5ytf.x5yr21d > div.x9f619.xjbqb8w > div > div.xjoudau.x6s0dn4 > .x1lugfcp.x19g9edo')[0]
search_place.clear()
search_place.send_keys(search_)


time.sleep(2)
search_enter = driver.find_elements(By.CSS_SELECTOR, 'div.x78zum5.xdt5ytf > div.x6s0dn4.x78zum5 > div.x9f619.x78zum5 > a.x1i10hfl.x1qjc9v5.xjbqb8w.xjqpnuy')[0]
search_enter.click()

time.sleep(5)
post_ = driver.find_elements(By.CSS_SELECTOR, 'div._aabd._aa8k._al3l')[0]
post_.click() 

time.sleep(3)
results = []
#수집할 게시글 수를 50개정도로 고정
for i in range(100):
  data = get_content(driver)
  results.append(data)
  print(data)
  is_next = move_next(driver)
  if is_next == False:
    break;
# Out:
# ['근황 조각집', []]
# ['(리그램) @ong___pho🌟✈️제주의 숨겨진 보석, 전국 5대 쌀국수의 자존심!🍜 옹포제주탑티어쌀국수집 ✨️🏝이곳은 단순한 식당이 아닙니다.마치 베트남의 한 가운데로 순간 이동한 듯한 강렬한 분위기로 여러분을 맞이합니다💫👫🌍전 세계에서 온 외국인 관광객들과제주도민들로 항상 북적이는 이곳! 제주도에 오셨다면 꼭 들러야 할 필수 코스! 🌴🌸🫕베트남 여사장님이 정성스럽게 끓여내는 쌀국수는해장은 물론, 입맛을 사로잡는 최고의 맛!"아직도 다른 해장국집에 가시나요?"라고 묻게 될 거에요. 🥘🌶🔥미나리 쌀국수, 고기가 듬뿍 담긴 매운 해장 쌀국수,그리고 연탄불에 구워내는 뚱뚱한 반미까지!이 모든 
# ['갑자기 흐려지고 얼어죽을뻔 했지만 그래서 더 이뻤던 목장', []]
# ['(광고)', ['제주도오션뷰펜션"천혜의 자연 환상의 섬 제주도 해뜨는 성"제주 동쪽에 위치한 오션뷰맛집 아름다운', '제주펜션 해뜨는 성☺------------제주 펜션 해뜨는 성---------------☺위치 : 제주 서귀포시 성산읍 한도로 267☺입실 : 15:00 / 퇴 실 : 11:00☺번호 : 010-2695-3380☺14평 / 18평 / 30평-----------------------------------------------', '제주도여행 중 "해뜨는 성"에서만 즐길 수 있는 포인트와콘텐츠들을 안내드리겠습니다♥ 넓고 깨끗한 제주 "가성비 펜션"☺ "올레1코스" 중간지점에 위치 해 "산책코스"☺ "성산일출봉" 입구까지 300M 객실에서 바로 감상할 수 있는 "아름다운 일출"☺ 바다 를 눈 앞에서 느낄 수 있는 "전 객실 오션 뷰"☺ 숙소 5분 거리에 조개 잡이 체험장과섭지코지에서의 해상레져, 오름에서 즐기는 승마체험까지!! "풍부한 주변 볼거리"☺\u200d친구,커플,가족들과 함께 아름다운 제주 ♥행복한 추억을 남길 수 있는 곳♥', '제주여행', '제주도', '제주도펜션', '제주도숙소', '제주도가볼만한곳', '성산일출봉펜션', '제주도숙소추천', '제주숙소', '제주숙소추천', '제주펜션추천', '서귀포펜션', '서귀포펜션추천']]
# ['제주정복', []]
# ['술톤 한몽키 다이어트 5일차🥹', []]
# ['(협찬) @cafe_the_light_jeju💗제주도에서 가장 핫한 제주카페💗 🐋오션뷰 카페 ✔카페더라이트❝ 성산일출봉과 바다를 한 눈에 볼 수 있는 뷰맛집 ❞………………《 🍮 제주 카페더라이트 》…………………📍 제주 서귀포시 성산읍 한도로 269 카페더라이트 📍⏰ 월~토 9:00 ~ 19:00🚷 매주 일요일 휴무📞 064-784-0080……………………………………………………………………………카페 전면 오션뷰 통창으로바다를 느낄 수 있는 "오션뷰카페"우도와 성산일출봉이 보이는 "루프탑 뷰맛집"인생샷을 남길 수 있는 포토존까지😍휴양지 느낌 가득 , 제주 느낌 가득한"야외좌석"도 있어요❣1층 2층 루프탑까지 넓은 카페만큼넓은 주차장까지👍✔️ 대표 메뉴1 "시그니처 라이트라떼(땅콩라떼)"✔️ 대표 메뉴2 "시그니처 제주아이스티"✔️ 대표 메뉴3 "한라봉 에이드"✔️디저트 ,베이커리 엄마손맛 수제!!웰빙 프리미엄 재료로 제주 특산품 한라봉을 이용한 디저트 !! “한라봉 몽블랑 ” 당근케익 베이커리 등 🎂 커플,친구,가족들과 함께 아름다운 제주를 느끼며소중한 시간을 보낼 수 있는 곳 💕……………………………………………………………………………', ['제주여행', '제주카페', '성산일출봉카페', '제주카페추천', '제주루프탑카페', '제주가볼만한곳', '제주도가볼만한곳', '제주여행코스', '제주도날씨', '제주서귀포카페추천', '제주가볼만한곳', '제주데이트', '제주도카페', '제주도맛집', '성산카페', '제주핫플', '제주핫플레이스', '제주핫플카페', '제주오션뷰카페', '제주카페투어', '제주도']]
# ['계속 이어지는 비로 춥게 느껴지는 것 같아요🥲따뜻하게 맛있게 준비해서 11시부터 브레이크타임 없이 운영합니다🙋\u200d♀️전 메뉴 포장 가능하며,도착 30분 전 전화주시면 시간 맞춰 포장 도와드리겠습니다🙆\u200d♀️오늘도 ', ['안녕하샌']]
# ['.키키의 라디오 모양 박스 안에사랑스러운 지지 쿠키가 가득!❤️바닐라, 황치즈, 초코,말차, 얼그레이, 5가지 맛으로고메 버터를 사용해🧈고급스러운 버터의 풍미가입안 가득 퍼져요!😋선물용으로도 적극 추천드리는💝"키키의 라디오 쿠키박스"를Koriko Cafe 연남점에서 만나보세요!🙌스튜디오 지브리 공식“마녀배달부 키키” 카페Koriko Cafe 연남점🥐11:00 - 20:00 (L.O-19:30)Koriko Cafe 제주점🥐OPENING SOON!', []]
# ['벌써 입춘이 왔다고 해서 올려보는 제주 가파도의 봄 🌼초록색과 노란색의 조합이 정말 예쁜 곳이자제주에서 봄이 가장 빠르게 왔다는 걸알 수 있는 가파도 유채꽃밭이에요!이번 비가 내리고 나면 제주에 봄이 올 것 같으니 저장해두었다가 개화 상태를 보고 방문하시면 좋을 거 같아요 :)📍 제주도, 가파도', []]
# ['(광고)', ['제주도오션뷰펜션"천혜의 자연 환상의 섬 제주도 해뜨는 성"제주 동쪽에 위치한 오션뷰맛집 아름다운', '제주펜션 해뜨는 성☺------------제주 펜션 해뜨는 성---------------☺위치 : 제주 서귀포시 성산읍 한도로 267☺입실 : 15:00 / 퇴 실 : 11:00☺번호 : 010-2695-3380☺14평 / 18평 / 30평-----------------------------------------------', '제주도여행 중 "해뜨는 성"에서만 즐길 수 있는 포인트와콘텐츠들을 안내드리겠습니다♥ 넓고 깨끗한 제주 "가성비 펜션"☺ "올레1코스" 중간지점에 위치 해 "산책코스"☺ "성산일출봉" 입구까지 300M 객실에서 바로 감상할 수 있는 "아름다운 일출"☺ 바다 를 눈 앞에서 느낄 수 있는 "전 객실 오션 뷰"☺ 숙소 5분 거리에 조개 잡이 체험장과섭지코지에서의 해상레져, 오름에서 즐기는 승마체험까지!! "풍부한 주변 볼거리"☺\u200d친구,커플,가족들과 함께 아름다운 제주 ♥행복한 추억을 남길 수 있는 곳♥', '제주여행', '제주도', '제주도펜션', '제주도숙소', '제주도가볼만한곳', '성산일출봉펜션', '제주도숙소추천', '제주숙소', '제주숙소추천', '제주펜션추천', '서귀포펜션', '서귀포펜션추천']]
# ['왜 설레냐 이 영상….💕내 새꾸 쫌 이뿌게 나왔넴….✨ \u202d', []]
# ['🐰 ', ['제주', '제주도', '용머리해안']]
# ['@space_muwi무위의 공간 : Space muwi-2 of 2아무것도 하지 않아도 되는 무위의 시간이 흐르는 공간쉼없이 내달렸던 나를 돌려세워 제주로 향하게 했던 무위의 공간!한경면 어느 한적하고 조용한 마을 안에 자리잡은 공간으로네이밍처럼 뭔가 블랙컬러로 감싸진 4개의 동이 이루고 있던 공간!블랙컬러가 주는 대비스러움인지는 몰라도 자연의 컬러와 더불어자연이 주는 아름다움을 더욱 비춰주고, 제주다움을 더한 공간인!제주다운 정원을 두고 3개의 동과 요가룸이 들어간 1개의 동까지오롯이 소리와 향, 그리고 온전히 내면에 집중 할 수 있으며,한적한 동네 주변을 산책하며 느끼는 감정들까지 뭔가 마음속쓸데없는 것들을 버리고 리프레쉬 가능한 힐링 스팟이지 않나!개인적으로 나무 흔들리는 소리, 새소리, 바람소리 들으며정원에 앉아서 멍때리고 있을 때, 이 좋았던 감정이 표현으로안되는게 아쉬울 정도로 나에게 리프레쉬 되는 소스였던!연박하며 다르게 구성된 조식은 왠만한 브런치카페 못지않은맛이 진짜! 라이트하면서도 건강까지 생각한 조식에 감탄을!호스트께서 알려주신대로 룸 내 비치된 싱잉볼을 쳐가며괜히 스트레칭도 해보고, 차도 마셔보고, 책도 읽고2박을 보내는 동안 무위의 공간이 아닌 치유의 공간으로변해있던 스테이지 않나! 일상에 지친 모두가 이 공간에서이 감정을 그대로 느끼고, 마음속까지 치유받기를 원하며! -', ['무위의공간A.제주시 한경면 명이1길 32 무위의 공T.체크인 16:00 / 체크아웃 11:00I.무 230.0-260.0 / 위 250.0-280.0 / 자 420.0-450.0 / 연 450.0-480.0웰컴티/조식서비스/전자레인지/인덕션/정수기/냉장고/와인잔다도세트/요가매트/요가서적/요가링/싱잉볼/자쿠지', '테싯_']]
# ['(협찬) @cafe_the_light_jeju💗제주도에서 가장 핫한 제주카페💗 🐋오션뷰 카페 ✔카페더라이트❝ 성산일출봉과 바다를 한 눈에 볼 수 있는 뷰맛집 ❞………………《 🍮 제주 카페더라이트 》…………………📍 제주 서귀포시 성산읍 한도로 269 카페더라이트 📍⏰ 월~토 9:00 ~ 19:00🚷 매주 일요일 휴무📞 064-784-0080……………………………………………………………………………카페 전면 오션뷰 통창으로바다를 느낄 수 있는 "오션뷰카페"우도와 성산일출봉이 보이는 "루프탑 뷰맛집"인생샷을 남길 수 있는 포토존까지😍휴양지 느낌 가득 , 제주 느낌 가득한"야외좌석"도 있어요❣1층 2층 루프탑까지 넓은 카페만큼넓은 주차장까지👍✔️ 대표 메뉴1 "시그니처 라이트라떼(땅콩라떼)"✔️ 대표 메뉴2 "시그니처 제주아이스티"✔️ 대표 메뉴3 "한라봉 에이드"✔️디저트 ,베이커리 엄마손맛 수제!!웰빙 프리미엄 재료로 제주 특산품 한라봉을 이용한 디저트 !! “한라봉 몽블랑 ” 당근케익 베이커리 등 🎂 커플,친구,가족들과 함께 아름다운 제주를 느끼며소중한 시간을 보낼 수 있는 곳 💕……………………………………………………………………………', ['제주여행', '제주카페', '성산일출봉카페', '제주카페추천', '제주루프탑카페', '제주가볼만한곳', '제주도가볼만한곳', '제주여행코스', '제주도날씨', '제주서귀포카페추천', '제주가볼만한곳', '제주데이트', '제주도카페', '제주도맛집', '성산카페', '제주핫플', '제주핫플레이스', '제주핫플카페', '제주오션뷰카페', '제주카페투어', '제주도']]

# %%
import pandas as pd
df = pd.DataFrame(results, columns = ['content', 'tags'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  28 non-null     object
#  1   tags     28 non-null     object
# dtypes: object(2)
# memory usage: 580.0+ bytes

# %%
df.head()
# Out:
#                                              content  \
# 0  (광고)제주도오션뷰펜션"천혜의 자연 환상의 섬 제주도 해뜨는 성"제주 동쪽에 위치한...
# 1                                               (광고)
# 2                                               (광고)
# 3  (광고)제주도오션뷰펜션"천혜의 자연 환상의 섬 제주도 해뜨는 성"제주 동쪽에 위치한...
# 4                                               (광고)
#
#                                                 tags
# 0  [제주도여행, 성산일출봉숙소, 제주여행, 제주도펜션, 제주도숙소, 제주도가볼만한곳,...
# 1  [제주도오션뷰펜션"천혜의 자연 환상의 섬 제주도 해뜨는 성"제주 동쪽에 위치한 오션...
# 2  [제주도오션뷰펜션"천혜의 자연 환상의 섬 제주도 해뜨는 성"제주 동쪽에 위치한 오션...
# 3  [제주도여행, 성산일출봉숙소, 제주여행, 제주도펜션, 제주도숙소, 제주도가볼만한곳,...
# 4  [제주도오션뷰펜션"천혜의 자연 환상의 섬 제주도 해뜨는 성"제주 동쪽에 위치한 오션...
